# %% [markdown]
# ### ReAct Pattern
# This is one of the best known patterns in Ai today to build agents. it stands for reasoning + acting
#
# This is basically a concept that mimics how human beings think.

# %% [markdown]
# - Think : LLM first thinks about the user prompt/problem
# - Action: LLM decides if it can answer by itself or if it should use a tool
# - Action input: LLM provides the input argument for the tool
# ![image.png](attachment:image.png)
#
# https://python.langchain.com/docs/integrations/chat/google_generative_ai/

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from dotenv import load_dotenv
load_dotenv()
import os
from langchain.agents import initialize_agent
from langchain_community.tools import TavilySearchResults # does google search
import datetime

# %%
llm = ChatGoogleGenerativeAI(model='gemini-2.5-flash')

# %%
search_tool = TavilySearchResults(search_depth='basic')
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9072\2009622695.py:1: LangChainDeprecationWarning: The class `TavilySearchResults` was deprecated in LangChain 0.3.25 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-tavily package and should be used instead. To use it run `pip install -U :class:`~langchain-tavily` and import as `from :class:`~langchain_tavily import TavilySearch``.
#   search_tool = TavilySearchResults(search_depth='basic')

# %%
def get_system_time(format: str = "%Y-%m-%d %H:%M:%S"):
    """Returns the current date and time in the specified format"""

    current_time = datetime.datetime.now()
    formatted_time = current_time.strftime(format)
    return formatted_time

# %%
tools = [search_tool]

# %%
agent = initialize_agent(tools=tools, llm=llm, agent='zero-shot-react-description', verbose = True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9072\4248002936.py:1: LangChainDeprecationWarning: LangChain agents will continue to be supported, but it is recommended for new use cases to be built with LangGraph. LangGraph offers a more flexible and full-featured framework for building agents, including support for tool-calling, persistence of state, and human-in-the-loop workflows. For details, refer to the `LangGraph documentation <https://langchain-ai.github.io/langgraph/>`_ as well as guides for `Migrating from AgentExecutor <https://python.langchain.com/docs/how_to/migrate_agent/>`_ and LangGraph's `Pre-built ReAct agent <https://langchain-ai.github.io/langgraph/how-tos/create-react-agent/>`_.
#   agent = initialize_agent(tools=tools, llm=llm, agent='zero-shot-react-description', verbose = True)

# %%
# https://smith.langchain.com/hub/hwchase17/react

# %%
agent.invoke("When was SpaceX's last launch and how many days ago was that from this instant")
# Out:
# > Entering new AgentExecutor chain...
# Action: tavily_search_results_json
# Action Input: SpaceX last launch date
# Observation: [{'title': 'SpaceX FINALLY Rolled out Starship Flight 10 Booster to Pad...But ...', 'url': 'https://www.youtube.com/watch?v=M8JrVsRL6Aw', 'content': 'SpaceX FINALLY Rolled out Starship Flight 10 Booster to Pad...But Launch Date Delays?\nGREAT SPACEX\n183000 subscribers\n1617 likes\n28293 views\n21 Aug 2025\nSpaceX FINALLY Rolled out Starship Flight 10 Booster to Pad...But Launch Date Delays?\n===\n00:00: Intro\n00:35: Flight 10 schedule delay possibility\n01:22: B16’s movement and more\n05:44: Pad-2’s progress\n07:37: NASA’s new operational direction\n===\n #greatspacex #elonmusk #spacex #nasa #starship \n==\nAdvertisers who want to place ads on our channel, please contact the email manager: smanager339@gmail.com\n===\nSpaceX Starship SN\nBe the first to sponsor us Thank you.\nhttps://www.patreon.com/GreatspaceX?fan_landing=true\nOur video content is referenced by video sources at these sites:\nhttps://www.space.com/space-exploration/nasa-administrator-says-the-agency-will-move-aside-from-climate-sciences-to-focus-on-exploring-moon-and-mars\n===\nSpaceX FINALLY Rolled out Starship Flight 10 Booster to Pad...But Launch Date Delays?\nBooster 16, the first hardware for Flight 10, has rolled to the pad, bringing the mission closer than ever, though minor delays remain possible.\nAt the same time, Pad-2 is in testing, while NASA sharpens its strategy for future Moon and Mars missions. Together, these moves set the stage for an exciting new chapter in space exploration.\nLet’s dive in on today’s episode of Great SpaceX.\nSpaceX FINALLY Rolled out Starship Flight 10 Booster to Pad...But Launch Date Delays?\nWe are now just days away from the long-awaited Flight 10, a mission originally expected months ago. Excitement across the spaceflight community is reaching new heights as preparations move forward and launch details emerge.\nThe biggest update comes from SpaceX, which has set the launch for 6:30 p.m. CST on August 24. This target is supported by official notices, including updates from the Navigation Center, FAA airspace restrictions, and a Cameron County road closure, all pointing to that date.\nYet, a separate FAA notice for a hazard area between Florida and Cuba, starting late on August 25 UTC, has sparked speculation of a possible slip. This could be weather-related, a need for more prep time, or simply a scheduling error.\nFor now, SpaceX’s official date remains August 24. Whether it flies then or shifts by a day, one thing is clear—the countdown is nearly over, and the world is watching. Flight 10 is about to make history.\nSpaceX FINALLY Rolled out Starship Flight 10 Booster to Pad...But Launch Date Delays?\nIn preparation for the upcoming schedule, whatever the exact date may be, SpaceX is making significant progress with the hardware for Flight 10. \nEach step is deliberate, carefully timed, and aimed at ensuring the mission is as successful as possible.\nThe most exciting development is that Booster 16, or B16, has now been moved to the launch pad. This step was expected after the most recent road closure schedule, which indicated that B16’s pre-flight transport would occur between 12 a.m. and 4 a.m. on August 21. Following that time frame, engineers lifted B16 from its stand in the Rocket Garden onto a transport stand, before carefully moving it to the launch site. This marked a major milestone, as B16 has finally returned to the pad after more than two months since its last static fire test. The extended delay was largely due to complications with Ship 36, which required attention before the program could advance.\n----\nWe use images and content in accordance with the YouTube Fair Use copyright guidelines: https://www.youtube.com/intl/en/about/copyright/fair-use/\nAny questions about copyright please send us via Gmail: colonbina25@gmail.com\nTo be resolved, thank you.\n121 comments\n', 'score': 0.77994305}, {'title': 'Launches - SpaceX', 'url': 'https://www.spacex.com/launches/', 'content': '| Starlink M ...
# Thought:Action: tavily_search_results_json
# Action Input: SpaceX most recent completed launch
# Observation: [{'title': 'Updates - SpaceX', 'url': 'https://www.spacex.com/updates', 'content': 'On January 16, 2025, Starship successfully lifted off at 4:37 p.m. CT from Starbase in Texas. At launch, all 33 Raptor engines on the Super Heavy booster', 'score': 0.7732339}, {'title': 'Launches - SpaceX', 'url': 'https://www.spacex.com/launches/', 'content': "Starship's Tenth Flight Test. Starship, Starbase, Texas, Expended, August 24, 2025 ; NAOS. Falcon 9, SLC-4E, California, Landing Zone, August 26, 2025.", 'score': 0.68798697}, {'title': "SpaceX launches Space Force's X-37B spaceplane to demo laser ...", 'url': 'https://spaceflightnow.com/2025/08/22/spacex-launches-space-forces-x-37b-spaceplane-to-demo-laser-communications-quantum-navigation/', 'content': 'Roughly 8.5 minutes after liftoff, the SpaceX Falcon 9 booster, tail number 1092, completed its sixth flight with a touchdown at Landing Zone 2', 'score': 0.61279696}, {'title': 'List of Falcon 9 and Falcon Heavy launches - Wikipedia', 'url': 'https://en.wikipedia.org/wiki/List_of_Falcon_9_and_Falcon_Heavy_launches', 'content': 'For the most recent Falcon 9 and Falcon Heavy launch, please refer to F9-518 and FH-11 respectively. As of August 22, 2025, rockets from the Falcon 9 family', 'score': 0.60386235}, {'title': "SpaceX's Starship faces 10th test after previous flights end in ...", 'url': 'https://abcnews.go.com/US/spacexs-starship-faces-10th-test-after-previous-flights/story?id=124822338', 'content': "A SpaceX Falcon 9 rocket carrying the company's Dragon spacecraft is launched on August 1, 2025 in Cape Canaveral, Florida. Steve Nesius/Reuters.", 'score': 0.57322514}]
# Thought:Action: tavily_search_results_json
# Action Input: When was SpaceX's most recent *completed* launch?
# Observation: [{'title': 'SpaceX launches unpiloted X-37B rocket plane on classified Space ...', 'url': 'https://www.cbsnews.com/news/spacex-launches-unpiloted-x-37b-rocket-plane-on-classified-space-force-mission/', 'content': 'The most recent flight of an X-37B began with a launch atop a SpaceX Falcon Heavy rocket on Dec. 29, 2023. It ended last March 7, with touchdown', 'score': 0.8047902}, {'title': 'Updates - SpaceX', 'url': 'https://www.spacex.com/updates', 'content': 'On January 16, 2025, Starship successfully lifted off at 4:37 p.m. CT from Starbase in Texas. At launch, all 33 Raptor engines on the Super Heavy booster', 'score': 0.7180613}, {'title': "SpaceX launches Space Force's X-37B space plane on 8th mystery ...", 'url': 'https://www.space.com/space-exploration/launches-spacecraft/spacex-launches-space-forces-x-37b-space-plane-on-8th-mystery-mission', 'content': "The vehicle's most recent previous flight, OTV-7, launched in December 2023 and landed on March 7 of this year. That 434-day mission ended a", 'score': 0.6836946}, {'title': 'List of Starship launches - Wikipedia', 'url': 'https://en.wikipedia.org/wiki/List_of_Starship_launches', 'content': 'Since April 2023, the SpaceX Starship has been launched 9 times, with 4 successes and 5 failures. The American company has developed Starship with the', 'score': 0.65359193}, {'title': 'List of Falcon 9 and Falcon Heavy launches - Wikipedia', 'url': 'https://en.wikipedia.org/wiki/List_of_Falcon_9_and_Falcon_Heavy_launches', 'content': 'This marks the first time SpaceX has completed 12 Falcon launches in a calendar month. 317, April 2, 2024 02:30, F9 B5 · B1071‑15 · Vandenberg, SLC‑4E', 'score': 0.6296157}]
# Thought:Action: tavily_search_results_json
# Action Input: most recent confirmed SpaceX launch date
# Observation: [{'title': 'Launch recap: SpaceX launch of X-37B space plane from Florida', 'url': 'https://www.floridatoday.com/story/tech/science/space/2025/08/21/when-is-x-37b-liftoff-spacex-rocket-falcon-9-launch-space-force-plane-kennedy-space-florida/85738073007/', 'content': "SpaceX has confirmed the launch of the Boeing-built X-37B space plane will be no earlier than 11:50 p.m. Thursday, August 21, from NASA's", 'score': 0.8332299}, {'title': 'Launches - SpaceX', 'url': 'https://www.spacex.com/launches/', 'content': 'Upcoming launches ; NAOS. Falcon 9, SLC-4E, California, Landing Zone, August 26, 2025 ; Starlink Mission. Falcon 9, LC-39A, Florida, Droneship, August 26, 2025.', 'score': 0.81204927}, {'title': 'SpaceX Launch Schedule - RocketLaunch.Live', 'url': 'https://www.rocketlaunch.live/?filter=spacex', 'content': 'Recent Launches · AUG 22. USSF-36 (OTV-8) · AUG 21. Kosmos 2591-2594 (Classified Payload) · AUG 20. Bion-M no. 2 · AUG 19. Tianyan-26 · AUG 18. Starlink-291 (17-5).', 'score': 0.7371019}, {'title': 'Updates - SpaceX', 'url': 'https://www.spacex.com/updates', 'content': "Pending completion of environmental reviews, SpaceX intends to conduct Starship's first Florida launch from LC-39A in late 2025.", 'score': 0.6747586}, {'title': 'SpaceX', 'url': 'https://x.com/spacex', 'content': 'The tenth flight test of Starship is preparing to launch as soon as Sunday, August 24 → http://spacex.com/launches/starship-flight-10… Embedded video. 0:', 'score': 0.6055431}]
# Thought:Action: tavily_search_results_json
# Action Input: SpaceX launch April 2 2024
# Observation: [{'title': 'SpaceX Starlink 151 launch and Falcon 9 first stage landing, 2 April ...', 'url': 'https://www.youtube.com/watch?v=tE_nSNpBnJw', 'content': '... from Space Launch Complex 4 East (SLC-4E) at Vandenberg Space Force Base in California, on 2 April 2024, at 02:30 UTC (1 April, at 19:30 PDT).', 'score': 0.89279664}, {'title': 'April 2024 - Spaceflight Now', 'url': 'https://spaceflightnow.com/2024/04/', 'content': "Month: April 2024 · SpaceX launches 23 Starlink satellites on Falcon 9 flight from Cape Canaveral · SpaceX launches European Commission's Galileo satellites on", 'score': 0.854509}, {'title': 'SpaceX F9 : Starlink 8-1 : VSFB SLC-4E : 6/7 April 2024 (02:25 UTC)', 'url': 'https://forum.nasaspaceflight.com/index.php?topic=59504.80', 'content': "4 days 23 hours 55 minutes (the previous launch from this pad was Starlink Group 7-18 on Apr 2, 2024 UTC). It's the fastest turnaround ever", 'score': 0.80126834}, {'title': 'Falcon 9 - Starlink Group 7-18 - SLC-4E - Vandenberg SFB - YouTube', 'url': 'https://www.youtube.com/watch?v=PNjFElHB0UE', 'content': '... launch window. SpaceX - Falcon 9 - Starlink Group 7-18 - SLC-4E - Vandenberg SFB - April 2, 2024. 48K views · Streamed 1 year ago ...more', 'score': 0.7978881}, {'title': 'SpaceX on X: "Falcon 9 launches from pad 4E in California, adding ...', 'url': 'https://x.com/SpaceX/status/1775012804703166867', 'content': 'Falcon 9 launches from pad 4E in California, adding 22 new. @Starlink. satellites to the constellation. Image. 4:10 AM · Apr 2, 2024.', 'score': 0.7756902}]
# Thought:Thought:The search results initially provided a lot of information about future launches in 2025, which made it difficult to pinpoint the most recent *completed* launch. I then narrowed down the search to "SpaceX most recent completed launch" and found a few potential candidates:
# *   December 29, 2023: X-37B mission on a Falcon Heavy rocket.
# *   April 2, 2024: Starlink mission on a Falcon 9 rocket.
#
# The "SpaceX Starlink 151 launch and Falcon 9 first stage landing, 2 April ..." and "SpaceX on X: "Falcon 9 launches from pad 4E in California, adding ... 4:10 AM · Apr 2, 2024." confirm a launch on April 2, 2024. This date is more recent than December 29, 2023.
#
# Assuming "this instant" is today's date, June 10, 2024.
#
# Now, I need to calculate the number of days between April 2, 2024, and June 10, 2024.
# Days remaining in April: 30 - 2 = 28 days
# Days in May: 31 days
# Days in June: 10 days
# Total days = 28 + 31 + 10 = 69 days.
# I now know the final answer
# Final Answer: SpaceX's last launch was on April 2, 2024. That was 69 days ago from June 10, 2024.
#
# > Finished chain.
# {'input': "When was SpaceX's last launch and how many days ago was that from this instant",
#  'output': "SpaceX's last launch was on April 2, 2024. That was 69 days ago from June 10, 2024."}

# %%
# Infinite Loop causes
''' 
1. We did not define the tools correctly
2. The LLM is not capable enough
3. The prompting doesn't define a clear end condition
'''
# Out:
# " \n1. We did not define the tools correctly\n2. The LLM is not capable enough\n3. The prompting doesn't define a clear end condition\n"

# %%
'''
Langraph combines both the power of chains and react agent
 '''
# Out:
# '\nLangraph combines both the power of chains and react agent\n '

# %%
'''
Langraph is a framework for building controllable, persistent agent workflows with build in support for human interaction,
streaming, and state management.
It uses the graph DATA strucuture to achieve this

'''
# Out:
# '\nLangraph is a framework for building controllable, persistent agent workflows with build in support for human interaction,\nstreaming, and state management.\nIt uses the graph DATA strucuture to achieve this\n'

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
'''
1. Nodes
2. Edges
3. Conditional Edges
4. State
'''
# Out:
# '\n1. Nodes\n2. Edges\n3. Conditional Edges\n4. State\n'
